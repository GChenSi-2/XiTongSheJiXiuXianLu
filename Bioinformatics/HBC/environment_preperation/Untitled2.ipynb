# %%
# 1. 变量与基本类型
x <- 10
y <- 3.14
name <- "Silicon"
is_ready <- TRUE
cat("x:", x, "\n")
cat("y:", y, "\n")
cat("名字:", name, "\n")
cat("boolean:", is_ready, "\n")
# Out:
# x: 10
# y: 3.14
# 名字: Silicon
# boolean: TRUE
